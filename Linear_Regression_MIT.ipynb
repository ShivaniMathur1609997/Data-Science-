# %%
#import the libraries
import pandas as pd
import numpy as np

# %%
#  Load the datasetC:\Users\Dell\Do
data = pd.read_csv("scrap price.csv")

# %% [markdown]
# Data Exploring

# %%
data.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# To Display All Rows and Columns. Do this when you wan to see all columns and Rows

pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
data.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible         rwd          front       88.6      168.8      64.1
# 1  convertible         rwd          front       88.6      168.8      64.1
# 2    hatchback         rwd          front       94.5      171.2      65.5
# 3        sedan         fwd          front       99.8      176.6      66.2
# 4        sedan         4wd          front       99.4      176.6      66.4
#
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.describe()
# Out:
#                ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.nunique()
# Out:
# ID                  205
# symboling             6
# name                147
# fueltypes             2
# aspiration            2
# doornumbers           2
# carbody               5
# drivewheels           3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
col = data.columns
col
# Out:
# Index(['ID', 'symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#To check all the integer, float and object columns seperately
intger_data = data.select_dtypes("int")
intger_data
# Out:
#       ID  symboling  curbweight  enginesize  horsepower  peakrpm  citympg  \
# 0      1          3        2548         130         111     5000       21
# 1      2          3        2548         130         111     5000       21
# 2      3          1        2823         152         154     5000       19
# 3      4          2        2337         109         102     5500       24
# 4      5          2        2824         136         115     5500       18
# 5      6          2        2507         136         110     5500       19
# 6      7          1        2844         136         110     5500       19
# 7      8          1        2954         136         110     5500       19
# 8      9          1        3086         131         140     5500       17
# 9     10          0        3053         131         160     5500       16
# 10    11          2        2395         108         101     5800       23
# 11    12          0        2395         108         101     5800       23
# ...

# %%
float_data = data.select_dtypes("float")
float_data
# Out:
#      wheelbase  carlength  carwidth  carheight  boreratio  stroke  \
# 0         88.6      168.8      64.1       48.8       3.47   2.680
# 1         88.6      168.8      64.1       48.8       3.47   2.680
# 2         94.5      171.2      65.5       52.4       2.68   3.470
# 3         99.8      176.6      66.2       54.3       3.19   3.400
# 4         99.4      176.6      66.4       54.3       3.19   3.400
# 5         99.8      177.3      66.3       53.1       3.19   3.400
# 6        105.8      192.7      71.4       55.7       3.19   3.400
# 7        105.8      192.7      71.4       55.7       3.19   3.400
# 8        105.8      192.7      71.4       55.9       3.13   3.400
# 9         99.5      178.2      67.9       52.0       3.13   3.400
# 10       101.2      176.8      64.8       54.3       3.50   2.800
# 11       101.2      176.8      64.8       54.3       3.50   2.800
# 12       101.2      176.8      64.8       54.3       3.31   3.190
# ...

# %%
float_data = data.select_dtypes("object")
float_data
# Out:
#                                 name fueltypes aspiration doornumbers  \
# 0                 alfa-romero giulia       gas        std         two
# 1                alfa-romero stelvio       gas        std         two
# 2           alfa-romero Quadrifoglio       gas        std         two
# 3                        audi 100 ls       gas        std        four
# 4                         audi 100ls       gas        std        four
# 5                           audi fox       gas        std         two
# 6                         audi 100ls       gas        std        four
# 7                          audi 5000       gas        std        four
# 8                          audi 4000       gas      turbo        four
# 9                audi 5000s (diesel)       gas      turbo         two
# 10                          bmw 320i       gas        std         two
# 11                          bmw 320i       gas        std        four
# ...

# %% [markdown]
# Data Preprocessing

# %%
encod_col = [ 'fueltypes', 'aspiration', 'doornumbers',
       'carbody', 'drivewheels', 'enginelocation','enginetype', 'cylindernumber',
       'fuelsystem']

# %%
data.nunique()
# Out:
# ID                  205
# symboling             6
# name                147
# fueltypes             2
# aspiration            2
# doornumbers           2
# carbody               5
# drivewheels           3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
#this code will make a dictionary which will represent which value got which encoding value
encod_dict = {}
for i in encod_col:
    ulist = list(data[i].unique())
    incod_dict = {}
    for n, u in enumerate(ulist):
        incod_dict[u] = n
    encod_dict[i] = incod_dict

# %%
encod_dict
# Out:
# {'fueltypes': {'gas': 0, 'diesel': 1},
#  'aspiration': {'std': 0, 'turbo': 1},
#  'doornumbers': {'two': 0, 'four': 1},
#  'carbody': {'convertible': 0,
#   'hatchback': 1,
#   'sedan': 2,
#   'wagon': 3,
#   'hardtop': 4},
#  'drivewheels': {'rwd': 0, 'fwd': 1, '4wd': 2},
#  'enginelocation': {'front': 0, 'rear': 1},
#  'enginetype': {'dohc': 0,
#   'ohcv': 1,
#   'ohc': 2,
#   'l': 3,
#   'rotor': 4,
#   'ohcf': 5,
#   'dohcv': 6},
#  'cylindernumber': {'four': 0,
#   'six': 1,
#   'five': 2,
#   'three': 3,
#   'twelve': 4,
#   'two': 5,
#   'eight': 6},
#  'fuelsystem': {'mpfi': 0,
#   '2bbl': 1,
#   'mfi': 2,
#   '1bbl': 3,
#   'spfi': 4,
#   '4bbl': 5,
#   'idi': 6,
#   'spdi': 7}}

# %%
datac = data.copy()

for i in encod_dict:
    datac[i] = datac[i].map(encod_dict[i])
datac.head(20)
# Out:
#     ID  symboling                      name  fueltypes  aspiration  \
# 0    1          3        alfa-romero giulia          0           0
# 1    2          3       alfa-romero stelvio          0           0
# 2    3          1  alfa-romero Quadrifoglio          0           0
# 3    4          2               audi 100 ls          0           0
# 4    5          2                audi 100ls          0           0
# 5    6          2                  audi fox          0           0
# 6    7          1                audi 100ls          0           0
# 7    8          1                 audi 5000          0           0
# 8    9          1                 audi 4000          0           1
# 9   10          0       audi 5000s (diesel)          0           1
# 10  11          2                  bmw 320i          0           0
# 11  12          0                  bmw 320i          0           0
# 12  13          0                    bmw x1          0           0
# ...

# %%
ndata = datac.drop(["ID","name"], axis=1)

# %%
#Seperated target and features
x = pd.DataFrame(ndata.iloc[:,:-1])
y = pd.DataFrame(ndata.iloc[:,-1])

# %%
x
# Out:
#      symboling  fueltypes  aspiration  doornumbers  carbody  drivewheels  \
# 0            3          0           0            0        0            0
# 1            3          0           0            0        0            0
# 2            1          0           0            0        1            0
# 3            2          0           0            1        2            1
# 4            2          0           0            1        2            2
# 5            2          0           0            0        2            1
# 6            1          0           0            1        2            1
# 7            1          0           0            1        3            1
# 8            1          0           1            1        2            1
# 9            0          0           1            0        1            2
# 10           2          0           0            0        2            0
# 11           0          0           0            1        2            0
# ...

# %%
y
# Out:
#          price
# 0    13495.000
# 1    16500.000
# 2    16500.000
# 3    13950.000
# 4    17450.000
# 5    15250.000
# 6    17710.000
# 7    18920.000
# 8    23875.000
# 9    17859.167
# 10   16430.000
# 11   16925.000
# 12   20970.000
# 13   21105.000
# 14   24565.000
# 15   30760.000
# 16   41315.000
# 17   36880.000
# 18    5151.000
# 19    6295.000
# 20    6575.000
# 21    5572.000
# 22    6377.000
# 23    7957.000
# 24    6229.000
# 25    6692.000
# 26    7609.000
# 27    8558.000
# 28    8921.000
# 29   12964.000
# 30    6479.000
# 31    6855.000
# 32    5399.000
# 33    6529.000
# 34    7129.000
# 35    7295.000
# 36    7295.000
# 37    7895.000
# 38    9095.000
# 39    8845.000
# 40   10295.000
# 41   12945.000
# 42   10345.000
# 43    6785.000
# 44    8916.500
# 45    8916.500
# 46   11048.000
# 47   32250.000
# 48   35550.000
# 49   36000.000
# 50    5195.000
# 51    6095.000
# 52    6795.000
# 53    6695.000
# 54    7395.000
# 55   10945.000
# 56   11845.000
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import *
import matplotlib.pyplot as plt
import seaborn as sns
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#shapes of splitted data
print("X_train:",x_train.shape)
print("X_test:",x_test.shape)
print("Y_train:",y_train.shape)
print("Y_test:",y_test.shape)
# Out:
# X_train: (164, 23)
# X_test: (41, 23)
# Y_train: (164, 1)
# Y_test: (41, 1)

# %% [markdown]
# Model training with sklearn

# %%
linreg=LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(x_test)
y_pred
# Out:
# array([[ 6163.41306486],
#        [18618.92676794],
#        [14964.19321271],
#        [ 4734.00234799],
#        [10587.45099838],
#        [11807.19844696],
#        [ 6943.04510343],
#        [ 5495.51792126],
#        [20850.36363368],
#        [ 6823.08448356],
#        [15590.34686411],
#        [31876.2759033 ],
#        [13019.99039789],
#        [12987.88982199],
#        [ 6567.21054563],
#        [13207.65614996],
#        [10998.93379426],
#        [19602.10582348],
#        [ 8673.59955139],
#        [ 7569.7044076 ],
#        [ 9924.84167394],
#        [17834.94440731],
#        [10859.76496686],
#        [13765.94223596],
#        [20442.02649919],
#        [ 7167.66512918],
#        [ 7177.26489573],
#        [18114.86997677],
#        [ 7779.40706805],
#        [ 5538.56501237],
#        [ 9086.92402831],
#        [11129.82787125],
#        [16731.92521449],
#        [ 9463.79418469],
#        [ 6834.25954774],
#        [23622.4130097 ],
#        [10383.41606603],
# ...

# %%
Accuracy=r2_score(y_test,y_pred)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is 81.98

# %%
# Functio to Calculate Adjusted R-Square
def Adj_Rsquare (model , X_train , y_train):
    RSquare = model.score( X_train, y_train)
    N = X_train.shape[0]
    K = X_train.shape[1]
    Adj_Rsquare_value = 1-((1-RSquare) * (N-1) / (N-K-1))
    return Adj_Rsquare_value

# %%
Adj_R2 = Adj_Rsquare(linreg,x_train , y_train)
print("Adjusted R-Square : ",Adj_R2)
# Out:
# Adjusted R-Square :  0.8996500701832957

# %% [markdown]
# R-squared (R2) score and adjusted R-squared (R2 adj) score are both used to evaluate the performance of regression models. R-squared is a statistical measure that represents the proportion of the variance in the dependent variable that is explained by the independent variable(s) in a regression model. R-squared ranges from 0 to 1, with higher values indicating better performance. However, as the number of independent variables increases, the R-squared value tends to increase, even if the added variables do not significantly improve the model. Therefore, it is not a reliable indicator of the model's quality when comparing models with different numbers of independent variables.
#
# Adjusted R-squared, on the other hand, adjusts the R-squared value to account for the number of independent variables in the model. It penalizes the addition of unnecessary independent variables that do not improve the model's performance. Adjusted R-squared ranges from -1 to 1, with higher values indicating better performance. Unlike R-squared, a higher adjusted R-squared value is always better than a lower value when comparing models with different numbers of independent variables.
#
# In summary, R-squared is a simple and commonly used metric for evaluating the goodness of fit of a regression model, while adjusted R-squared is a modified version of R-squared that accounts for the number of independent variables in the model and is therefore more reliable when comparing models with different numbers of independent variables.

# %%
plt.scatter(y_test,y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted');

# %%
sns.regplot(x=y_test,y=y_pred,ci=None,color ='red');

# %% [markdown]
# Mean Squared Error represents the average of the squared difference between the original and predicted values in the data set. It measures the variance of the residuals.
#
#
# ![image.png](data:image/png;base64,...)

# %%
mse_on_test = mean_squared_error(y_test, y_pred, squared=True)
mse_on_test
# Out:
# 13948366.338050433

# %% [markdown]
# Root Mean Squared Error is the square root of Mean Squared error. It measures the standard deviation of residuals.
#
# ![image.png](data:image/png;base64,...)

# %%
rmse_on_test = mean_squared_error(y_test, y_pred, squared=False)
rmse_on_test
# Out:
# 3734.751174850934

# %% [markdown]
# The Mean absolute error represents the average of the absolute difference between the actual and predicted values in the dataset. It measures the average of the residuals in the dataset.
#
#
# ![image.png](data:image/png;base64,...)

# %%
mape_on_test= mean_absolute_percentage_error(y_test, y_pred)
mape_on_test
# Out:
# 0.15315864015843605

# %% [markdown]
# The lower value of MAE, MSE, and RMSE implies higher accuracy of a regression model.
#
# However, a higher value of R square is considered desirable.
